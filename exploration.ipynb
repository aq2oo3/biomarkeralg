# %%
import pandas as pd
df = pd.read_csv('new_parsed_TBI.csv')
display(df.head(10))
# Out:
#     source                  id  ADB/gfap  ADB/ngrn  ADB/st2  ADB/bdnf  GCS
# 0  Control   HMN1243394A (01M)       5.0       0.0  14508.5     367.5   15
# 1  Control   HMN1243395A (02M)       4.5       0.0  11048.5     315.5   15
# 2  Control   HMN1243396A (03M)       6.0       0.0   7386.0     746.0   15
# 3  Control   HMN1243398A (04M)      16.5      75.0   5064.5     367.5   15
# 4  Control   HMN1243400A (05M)       8.0       1.0   8363.0     387.5   15
# 5  Control   HMN1243406A (06M)       5.0       0.0   7630.0     397.5   15
# 6  Control   HMN1243433A (07M)       7.5       0.0  10373.0     367.5   15
# 7  Control   HMN1243434A (08M)       2.5       0.0   8638.0     665.5   15
# 8  Control   HMN1243435A (09M)       4.0       0.0  14947.0     355.5   15
# 9  Control  HMN1243446A (010M)       3.5       1.5  23514.0     535.0   15

# %%
df_control = df[df['source'] == 'Control']
df_tbi = df[df['source'] == 'TBI']
display(df_control.head(10))
display(df_tbi.head(10))
# Out:
#     source                  id  ADB/gfap  ADB/ngrn  ADB/st2  ADB/bdnf  GCS
# 0  Control   HMN1243394A (01M)       5.0       0.0  14508.5     367.5   15
# 1  Control   HMN1243395A (02M)       4.5       0.0  11048.5     315.5   15
# 2  Control   HMN1243396A (03M)       6.0       0.0   7386.0     746.0   15
# 3  Control   HMN1243398A (04M)      16.5      75.0   5064.5     367.5   15
# 4  Control   HMN1243400A (05M)       8.0       1.0   8363.0     387.5   15
# 5  Control   HMN1243406A (06M)       5.0       0.0   7630.0     397.5   15
# 6  Control   HMN1243433A (07M)       7.5       0.0  10373.0     367.5   15
# 7  Control   HMN1243434A (08M)       2.5       0.0   8638.0     665.5   15
# 8  Control   HMN1243435A (09M)       4.0       0.0  14947.0     355.5   15
# 9  Control  HMN1243446A (010M)       3.5       1.5  23514.0     535.0   15
#    source          id  ADB/gfap  ADB/ngrn  ADB/st2  ADB/bdnf  GCS
# 40    TBI  KH24-08560    1145.0       8.0  93554.0    1425.0   14
# ...

# %%
from matplotlib import pyplot as plt

x = df_control['GCS']
y = df_tbi['GCS']

plt.hist([x, y], label=['Control', 'TBI'])
plt.legend(loc='upper right')
plt.show()

# %%
x = df_control['ADB/gfap']
y = df_tbi['ADB/gfap']

plt.hist([x, y], label=['Control', 'TBI'])
plt.legend(loc='upper right')
plt.show()

# %%
x = df_control['ADB/ngrn']
y = df_tbi['ADB/ngrn']

plt.hist([x, y], label=['Control', 'TBI'])
plt.legend(loc='upper right')
plt.show()

# %%
x = df_control['ADB/st2']
y = df_tbi['ADB/st2']

plt.hist([x, y], label=['Control', 'TBI'])
plt.legend(loc='upper right')
plt.show()

# %%
x = df_control['ADB/bdnf']
y = df_tbi['ADB/bdnf']

plt.hist([x, y], label=['Control', 'TBI'])
plt.legend(loc='upper right')
plt.show()

# %%
df2 = pd.read_csv('new_parsed_AD2.csv')
df2_control = df2[df2['source'] == 'Control']
df2_ad = df2[df2['source'] != 'Control']
display(df2_control.head(10))
display(df2_ad.head(10))
# Out:
#     source                  id  ADB/ab40  ADB/ab42  ADB/tau181  ADB/tau217  \
# 0  Control   HMN1243394A (01M)     17.80      1.70         0.1         0.1
# 1  Control   HMN1243395A (02M)      2.90      2.45         0.1         0.1
# 2  Control   HMN1243396A (03M)     23.50      3.30         0.1         0.1
# 3  Control   HMN1243398A (04M)    667.15    451.00         0.1         2.2
# 4  Control   HMN1243400A (05M)     93.70      7.80         0.1         2.6
# 5  Control   HMN1243406A (06M)     41.90      1.95         0.1         0.1
# 6  Control   HMN1243433A (07M)      5.70      0.60         0.1         0.1
# 7  Control   HMN1243434A (08M)     30.80      1.40         0.1         0.1
# 8  Control   HMN1243435A (09M)     19.00      3.85         0.1         8.3
# 9  Control  HMN1243446A (010M)     47.65     15.00         0.1         0.1
#
#    MMSE
# 0  20.0
# 1  20.0
# 2  20.0
# 3  20.0
# 4  20.0
# 5  20.0
# 6  20.0
# 7  20.0
# 8  20.0
# 9  20.0
# ...

# %%
x = df2_control['ADB/ab40']
y = df2_ad['ADB/ab40']

plt.hist([x, y], label=['Control', 'AD'])
plt.legend(loc='upper right')
plt.show()

# %%
x = df2_control['ADB/ab42']
y = df2_ad['ADB/ab42']

plt.hist([x, y], label=['Control', 'AD'])
plt.legend(loc='upper right')
plt.show()

# %%
x = df2_control['ADB/tau181']
y = df2_ad['ADB/tau181']

plt.hist([x, y], label=['Control', 'AD'])
plt.legend(loc='upper right')
plt.show()

# %%
x = df2_control['ADB/tau217']
y = df2_ad['ADB/tau217']

plt.hist([x, y], label=['Control', 'AD'])
plt.legend(loc='upper right')
plt.show()
